# %% [markdown]
# # LOAD PIPELINE

# %%
import joblib

pipeline = joblib.load(
    "loan_approval_pipeline.pkl"
)

pipeline.keys()
# Out:
# dict_keys(['model', 'features', 'imputer'])

# %% [markdown]
# # EXTRACTING COMPONENTS

# %%
model = pipeline["model"]
features = pipeline["features"]
imputer = pipeline["imputer"]

print(features)
# Out:
# ['person_age', 'person_income', 'person_home_ownership', 'person_emp_length', 'loan_grade', 'loan_amnt', 'loan_int_rate', 'loan_percent_income', 'cb_person_default_on_file', 'cb_person_cred_hist_length', 'loan_intent_EDUCATION', 'loan_intent_HOMEIMPROVEMENT', 'loan_intent_MEDICAL', 'loan_intent_PERSONAL', 'loan_intent_VENTURE', 'loan_to_income_ratio', 'financial_burden', 'income_per_year_emp', 'cred_hist_to_age_ratio', 'int_to_loan_ratio', 'loan_int_emp_interaction', 'debt_to_credit_ratio', 'int_to_cred_hist', 'int_per_year_emp', 'loan_amt_per_emp_year', 'income_to_loan_ratio']

# %% [markdown]
# # CREATING SAMPLE CUSTOMER

# %%
sample = {
    'person_age': 30,
    'person_income': 60000,
    'person_home_ownership': 1,
    'person_emp_length': 5,
    'loan_grade': 2,
    'loan_amnt': 10000,
    'loan_int_rate': 12,
    'loan_percent_income': 0.16,
    'cb_person_default_on_file': 0,
    'cb_person_cred_hist_length': 8,
    'loan_intent_EDUCATION': 0,
    'loan_intent_HOMEIMPROVEMENT': 0,
    'loan_intent_MEDICAL': 0,
    'loan_intent_PERSONAL': 1,
    'loan_intent_VENTURE': 0,
    'loan_to_income_ratio': 10000/60000,
    'financial_burden': 10000*12,
    'income_per_year_emp': 60000/5,
    'cred_hist_to_age_ratio': 8/30,
    'int_to_loan_ratio': 12/10000,
    'loan_int_emp_interaction': 10000*5,
    'debt_to_credit_ratio': 10000/8,
    'int_to_cred_hist': 12/8,
    'int_per_year_emp': 12/5,
    'loan_amt_per_emp_year': 10000/5,
    'income_to_loan_ratio': 60000/10000
}

# %% [markdown]
# # PREDICTION
